# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-06a55272-c946-4e05-9208-0286237014b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06a55272-c946-4e05-9208-0286237014b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pikepdf


while True:

    pass_ = 'Free Palestine'
    password = input('Enter the password: ')

    if pass_ == password:

        try :

            print('\n' + '-' * 39 + ' Welcome to "Python3 Based PDF Protector" \U0001F44B\U0001F44B\U0001F44B ' + '-' * 38)

            name = input('\nDear user! Please enter your name: ')

            print(f'\n\U0001F4E3 Hi {name}!\n\U0001F6A8 Upload your PDF on Coding Platform')

            print(f'\n\U0001F6A8 Enter the following details carefully!')

            oldpdfname = input('\nEnter the current name of the PDF you want to protect (without .pdf extension): ')

            # Open the existing PDF
            oldpdf = pikepdf.Pdf.open(f'{oldpdfname}.pdf')

            extr = input('Would you allow users to copy material from your new protected PDF file (yes/no)?: ')

            if extr == 'yes':
                extr = True
            elif extr == 'no':
                extr = False
            else:
                print('\nPlease enter valid input! i.e: yes/no')
                extr = None  # To handle invalid input

            if extr is not None:
                no_extr = pikepdf.Permissions(extract=extr)  # Define permissions

                fileloc = input('Enter a valid file location where you want to save your file, e.g., C:/Users/HP/Downloads: ')
                new_name = input('Enter a new name for your PDF (without .pdf extension): ')

                print('\n\U0001F4E3 Anyone who wants to open the PDF will need to provide this user password!')
                user_pass = input('\nCreate a user password: ')

                print('\n\U0001F4E3The owner password has more privileges than the user password, such as the ability to modify permissions and decrypt the document completely.')
                owner_pass = input('\nEnter owner password: ')

                # Save the PDF with encryption
                oldpdf.save(f'{fileloc}/{new_name}.pdf',
                            encryption=pikepdf.Encryption(user=user_pass,
                                                           owner=owner_pass,
                                                           allow=no_extr))

                perm = 'Granted' if extr else 'Denied'

                print('\n' + '\t\t   ' + '-' * 25 + ' \U0001F389 The process has been completed! \U0001F389 ' + '-' * 25 + '\t\t\t\t')
                print(f'\nDear {name}! Your PDF Document has been protected \U0001F64C!')
                print('\n\n\U00002139 Your PDF Document Details:\n')
                print(f'Previous Name: {oldpdfname}.pdf\nNew Name: {new_name}.pdf\nFile Location: {fileloc}\nUser Password: {user_pass}\nOwner Password: {owner_pass}\nMaterial Extracting Permission: {perm}')
            else:
                print('Process aborted due to invalid input for extraction permission.')

        except:
            print('\n\U0001F6A8\U0001F6A8 Enter valid input!')

    else:
        print('\n\U0000274C \U0000274C \U0000274C\nIncorrect Password!\nAccess Denied.')

    run = input('\nWanna run again?(y/n): ')

    if run != 'y':
        print('\n\U0001F44B \U0001F44B \U0001F44B\nYou choosed to exit!\nGood Bye')
        break

    print('\n The Output will be:\n\nEnter the password: Free Palestine

--------------------------------------- Welcome to "Python3 Based PDF Protector" 👋👋👋 --------------------------------------

Dear user! Please enter your name: Rayyan Ahmed

📣 Hi Rayyan Ahmed!
🚨 Upload your PDF on Coding Platform

🚨 Enter the following details carefully!

Enter the current name of the PDF you want to protect (without .pdf extension): my cv 1
Would you allow users to copy material from your new protected PDF file (yes/no)?: yes
Enter a valid file location where you want to save your file, e.g., C:/Users/HP/Downloads: C:/Users/HP/Downloads
Enter a new name for your PDF (without .pdf extension): mycv1

📣 Anyone who wants to open the PDF will need to provide this user password!

Create a user password: my cv 1

📣The owner password has more privileges than the user password, such as the ability to modify permissions and decrypt the document completely.

Enter owner password: Rayyan Ahmed

		   ------------------------- 🎉 The process has been completed! 🎉 -------------------------

Dear Rayyan Ahmed! Your PDF Document has been protected 🙌!


ℹ Your PDF Document Details:

Previous Name: my cv 1.pdf
New Name: mycv1.pdf
File Location: C:/Users/HP/Downloads
User Password: my cv 1
Owner Password: Rayyan Ahmed
Material Extracting Permission: Granted

Wanna run again?(y/n): n

👋 👋 👋
You choosed to exit!
Good Bye
1
​')
